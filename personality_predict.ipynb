# %% [markdown]
# <a href="https://colab.research.google.com/github/zeeshanchand/predict_personality/blob/main/personality_predict.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data_raw=pd.read_csv("data-final.csv",sep= '\t')
data = data_raw.copy()
pd.options.display.max_columns = 150
data.drop(data.columns[50:107], axis=1, inplace=True)
data.drop(data.columns[51:], axis=1, inplace=True)

data = data[data.index.get_level_values(0).isin(data.index.get_level_values(0))]
print('Number of participants: ', len(data))
data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f764e6a4775e> in <cell line: 1>()
# ----> 1 data_raw=pd.read_csv("data-final.csv",sep= '\t')
#       2 data = data_raw.copy()
#       3 pd.options.display.max_columns = 150
#       4 data.drop(data.columns[50:107], axis=1, inplace=True)
#       5 data.drop(data.columns[51:], axis=1, inplace=True)
#
# NameError: name 'pd' is not defined

# %%
from sklearn.cluster import KMeans
df_model = data.drop('country', axis=1)

# %%
kmeans = KMeans(n_clusters=5)
k_fit = kmeans.fit(df_sample)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
df_sample = pd.DataFrame({'x': [1, 2, 3, 4, 5], 'y': [6, 7, 8, 9, 10]})
kmeans = KMeans(n_clusters=5)
k_fit = kmeans.fit(df_sample)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
pd.options.display.max_columns = 10

# %%
predictions = k_fit.labels_
df_sample['Clusters'] = predictions
df_sample.head(10)
# Out:
#    x   y  Clusters
# 0  1   6         1
# 1  2   7         2
# 2  3   8         4
# 3  4   9         3
# 4  5  10         0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_21['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_22['x'].plot(kind='hist', bins=20, title='x')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_23['y'].plot(kind='hist', bins=20, title='y')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_24['Clusters'].plot(kind='hist', bins=20, title='Clusters')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
# ...

# %%
import seaborn as sns
plt.figure(figsize=(10,10))
df_pca = pd.DataFrame({'PCA1': [1, 2, 3, 4, 5], 'PCA2': [6, 7, 8, 9, 10], 'Cluster': ['A', 'B', 'C', 'D', 'E']})
sns.scatterplot(data=df_pca, x='PCA1', y='PCA2', hue='Cluster')
plt.title('Personality Clusters after PCA')
# Out:
# Text(0.5, 1.0, 'Personality Clusters after PCA')

# %%
import matplotlib.pyplot as plt
